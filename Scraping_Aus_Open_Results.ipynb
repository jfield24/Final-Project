# %%
import pandas as pd

# %%
# First url to scrape
url1="http://old.xscores.com/tennis/livescores/08-02"

# %%
# Reading in the html file
tables1=pd.read_html(url1)
tables1
# Out:
# [                                                   0                 1   \
#  0                                      FINISHED GAMES    FINISHED GAMES
#  1                                                 K/O              Stat
#  2                                    AUS-OPEN (ATP-S)  AUS-OPEN (ATP-S)
#  3                                               11:50               Fin
#  4                                               11:35               Fin
#  ..                                                ...               ...
#  85                                                NaN               NaN
#  86                                              Sched         Scheduled
#  87                                                Fin          Finished
#  88                                                Int       Interrupted
#  89  getLocation(); /* This jsp is included in each...               NaN
#
#                    2                 3                 4                 5   \
# ...

# %%
df1=tables1[1]
df1
# Out:
#                                                    0                 1   \
# 0                                      FINISHED GAMES    FINISHED GAMES
# 1                                                 K/O              Stat
# 2                                    AUS-OPEN (ATP-S)  AUS-OPEN (ATP-S)
# 3                                               11:50               Fin
# 4                                               11:35               Fin
# ..                                                ...               ...
# 85                                                NaN               NaN
# 86                                              Sched         Scheduled
# 87                                                Fin          Finished
# 88                                                Int       Interrupted
# 89  getLocation(); /* This jsp is included in each...               NaN
#
#                   2                 3                 4                 5   \
# ...

# %%
url2="http://old.xscores.com/tennis/livescores/09-02"
tables2=pd.read_html(url2)
df2=tables2[1]
df2
# Out:
#                                                     0                 1   \
# 0                                       FINISHED GAMES    FINISHED GAMES
# 1                                                  K/O              Stat
# 2                                     AUS-OPEN (ATP-S)  AUS-OPEN (ATP-S)
# 3                                                11:25               Fin
# 4                                                10:20               Fin
# ..                                                 ...               ...
# 111                                                NaN               NaN
# 112                                              Sched         Scheduled
# 113                                                Fin          Finished
# 114                                                Int       Interrupted
# 115  getLocation(); /* This jsp is included in each...               NaN
#
#                    2                 3                 4                 5   \
# ...

# %%
url3="http://old.xscores.com/tennis/livescores/10-02"
tables3=pd.read_html(url3)
df3=tables3[1]
df3
# Out:
#                                                     0                 1   \
# 0                                       FINISHED GAMES    FINISHED GAMES
# 1                                                  K/O              Stat
# 2                                     AUS-OPEN (ATP-S)  AUS-OPEN (ATP-S)
# 3                                                13:10               Fin
# 4                                                11:45               Fin
# ..                                                 ...               ...
# 113                                                NaN               NaN
# 114                                              Sched         Scheduled
# 115                                                Fin          Finished
# 116                                                Int       Interrupted
# 117  getLocation(); /* This jsp is included in each...               NaN
#
#                    2                 3                 4                 5   \
# ...

# %%
url4="http://old.xscores.com/tennis/livescores/11-02"
tables4=pd.read_html(url4)
df4=tables4[1]
df4
# Out:
#                                                     0                 1   \
# 0                                       FINISHED GAMES    FINISHED GAMES
# 1                                                  K/O              Stat
# 2                                     AUS-OPEN (ATP-S)  AUS-OPEN (ATP-S)
# 3                                                12:45               Fin
# 4                                                12:25               Fin
# ..                                                 ...               ...
# 100                                                NaN               NaN
# 101                                              Sched         Scheduled
# 102                                                Fin          Finished
# 103                                                Int       Interrupted
# 104  getLocation(); /* This jsp is included in each...               NaN
#
#                    2                 3                 4                 5   \
# ...

# %%
url5="http://old.xscores.com/tennis/livescores/12-02"
tables5=pd.read_html(url5)
df5=tables5[1]
df5
# Out:
#                                                    0                 1   \
# 0                                      FINISHED GAMES    FINISHED GAMES
# 1                                                 K/O              Stat
# 2                                    AUS-OPEN (ATP-S)  AUS-OPEN (ATP-S)
# 3                                               11:45               Fin
# 4                                               10:20               Fin
# ..                                                ...               ...
# 70                                                NaN               NaN
# 71                                              Sched         Scheduled
# 72                                                Fin          Finished
# 73                                                Int       Interrupted
# 74  getLocation(); /* This jsp is included in each...               NaN
#
#                   2                 3                 4                 5   \
# ...

# %%
url6="http://old.xscores.com/tennis/livescores/13-02"
tables6=pd.read_html(url6)
df6=tables6[1]
df6
# Out:
#                                                    0                 1   \
# 0                                      FINISHED GAMES    FINISHED GAMES
# 1                                                 K/O              Stat
# 2                                    AUS-OPEN (ATP-S)  AUS-OPEN (ATP-S)
# 3                                               12:00               Fin
# 4                                               12:00               Fin
# ..                                                ...               ...
# 79                                                NaN               NaN
# 80                                              Sched         Scheduled
# 81                                                Fin          Finished
# 82                                                Int       Interrupted
# 83  getLocation(); /* This jsp is included in each...               NaN
#
#                   2                 3                 4                 5   \
# ...

# %%
url7="http://old.xscores.com/tennis/livescores/14-02"
tables7=pd.read_html(url7)
df7=tables7[1]
df7
# Out:
#                                                    0                 1   \
# 0                                      FINISHED GAMES    FINISHED GAMES
# 1                                                 K/O              Stat
# 2                                    AUS-OPEN (ATP-S)  AUS-OPEN (ATP-S)
# 3                                               12:30               Fin
# 4                                               09:45               Fin
# ..                                                ...               ...
# 56                                                NaN               NaN
# 57                                              Sched         Scheduled
# 58                                                Fin          Finished
# 59                                                Int       Interrupted
# 60  getLocation(); /* This jsp is included in each...               NaN
#
#                   2                 3                 4                 5   \
# ...

# %%
url8="http://old.xscores.com/tennis/livescores/15-02"
tables8=pd.read_html(url8)
df8=tables8[2]
df8
# Out:
#                                                    0                   1   \
# 0                                                 K/O                Stat
# 1                                   CHI-CON (CHAL MS)   CHI-CON (CHAL MS)
# 2                                               16:00               Sched
# 3                                               17:30               Sched
# 4                                               19:00               Sched
# ..                                                ...                 ...
# 74                                 SAF-POT2 (CHAL MS)  SAF-POT2 (CHAL MS)
# 75                                              12:40                 Fin
# 76                                                NaN                 NaN
# 77  getLocation(); /* This jsp is included in each...                 NaN
# 78  K/O Stat Tour Tournament Round Player 1 SP Pla...                 NaN
#
#                     2                   3                   4   \
# ...

# %%
dflist = [df1, df2, df3, df4, df5, df6, df7, df8]
df_all = pd.concat(dflist)

# %%
df_all
# Out:
#                                                    0                   1   \
# 0                                      FINISHED GAMES      FINISHED GAMES
# 1                                                 K/O                Stat
# 2                                    AUS-OPEN (ATP-S)    AUS-OPEN (ATP-S)
# 3                                               11:50                 Fin
# 4                                               11:35                 Fin
# ..                                                ...                 ...
# 74                                 SAF-POT2 (CHAL MS)  SAF-POT2 (CHAL MS)
# 75                                              12:40                 Fin
# 76                                                NaN                 NaN
# 77  getLocation(); /* This jsp is included in each...                 NaN
# 78  K/O Stat Tour Tournament Round Player 1 SP Pla...                 NaN
#
#                     2                   3                   4   \
# ...

# %%
# Some cleaning
aus_open_df = df_all[df_all[2] == 'ATP-S']
aus_open_df
# Out:
#        0      1      2         3     4    5                         6    7   \
# 3   11:50    Fin  ATP-S  AUS-OPEN  R128  NaN       SHAPOVALOV D. (CAN)   11
# 4   11:35    Fin  ATP-S  AUS-OPEN  R128  NaN         DJOKOVIC N. (SRB)    1
# 5   11:00    Fin  ATP-S  AUS-OPEN  R128  NaN           DANIEL T. (JPN)   LL
# 6   10:15    Fin  ATP-S  AUS-OPEN  R128  NaN   FERREIRA SILVA F. (POR)    Q
# 7   09:45  P1Ret  ATP-S  AUS-OPEN  R128  NaN           SUGITA Y. (JPN)  NaN
# ..    ...    ...    ...       ...   ...  ...                       ...  ...
# 6   03:40    Fin  ATP-S  AUS-OPEN   R16  NaN  AUGER-ALIASSIME F. (CAN)   20
# 21  11:30   P1WO  ATP-S  AUS-OPEN   R16  NaN        TSITSIPAS S. (GRE)    5
# 22  06:25    Fin  ATP-S  AUS-OPEN   R16  NaN          FOGNINI F. (ITA)   16
# 23  05:55  P2Ret  ATP-S  AUS-OPEN   R16  NaN           RUBLEV A. (RUS)    7
# 24  04:05    Fin  ATP-S  AUS-OPEN   R16  NaN         MCDONALD M. (USA)   PR
#
# ...

# %%
# Push to CSV
aus_open_df.to_csv("aus-open-2021-data/aus-open-2021-results.csv", index=False)
